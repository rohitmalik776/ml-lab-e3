# %%
import pandas as pd

# %%
# Import csv data and store it in pandas DataFrame.
data = pd.read_csv('Iris.csv')

# %%
# Plot Histogram from DataFrame.
data.hist(bins = data['Id'].count())
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# #### Plot various scatter-plots of the given DataFrame.

# %%
data.plot.scatter(x='Id', y='SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SepalLengthCm'>

# %%
data.plot.scatter(x='Id', y='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SepalWidthCm'>

# %%
data.plot.scatter(x='Id', y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='Id', ylabel='PetalLengthCm'>

# %%
data.plot.scatter(x='Id', y='PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='Id', ylabel='PetalWidthCm'>

# %%
data.plot.scatter(x='Id', y='Species')
# Out:
# <AxesSubplot:xlabel='Id', ylabel='Species'>

# %%
data.plot.scatter(x='Species', y='PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
data.plot.scatter(x='SepalWidthCm', y='SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='SepalLengthCm'>
